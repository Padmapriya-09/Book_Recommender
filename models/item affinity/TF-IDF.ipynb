# %%
# basics
import pandas as pd
import numpy as np
import collections

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# tools
import scipy
import math
import random
import sklearn
import string
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split

import nltk
nltk.download('stopwords')

# # handle from here
finalbooks = pd.read_csv('finalbooks.csv')
ratings = pd.read_csv('finalratings.csv')
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\NITEESHA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
## NDGC & RMSE

def dcg_k(r, k):
    """ Discounted Cumulative Gain (DGC)  
    Args:
        r: True Ratings in Predicted Rank Order (1st element is top recommendation)
        k: Number of results to consider
    Returns:
        DCG
    """
  
    r = np.asfarray(r)[:k]
    return np.sum(2**r / np.log2(np.arange(2, r.size + 2)))      



def ndcg_k(r, k):
    """Normalized Discounted Cumulative Gain (NDCG)
    Args:
        r: True Ratings in Predicted Rank Order (1st element is top recommendation)
        k: Number of results to consider
    Returns:
        NDCG
    """
    dcg_max = dcg_k(sorted(r, reverse=True), k)
    if not dcg_max:
        return 0.
    return dcg_k(r, k) / dcg_max

def mean_ndcg(rs):
    """Mean NDCG for all users
    Args:
        rs: Iterator / For each user: True Ratings in Predicted Rank Order
    Returns:
        Mean NDCG
    """
    return np.mean([ndcg_k(r, len(r)) for r in rs])

def rmse(y,h):
    """RMSE
    Args:
        y: real y
        h: predicted y
    Returns:
        RMSE
    """
    a = y-h

    return np.sqrt(sum(a**2)/len(a))

# %%
## DEFINING THE TAIL
tailcomp = ratings.groupby(by= 'newbookid', as_index=False).agg({'rating':pd.Series.count}).sort_values(by = 'rating', ascending = False)
tot = sum(tailcomp['rating'])
tailcomp['popshare']= [x/tot for x in tailcomp['rating']]
tailcomp['popshare']= tailcomp['popshare'].cumsum()
tailcomp['category']= ['Head' if x<0.95 else "Tail" for x in tailcomp['popshare']]

tail = tailcomp.loc[tailcomp.popshare >= 0.95]
tail
# Out:
#       newbookid  rating  popshare category
# 5458       6115      35  0.950003     Tail
# 4776       5341      35  0.950036     Tail
# 4154       4641      35  0.950069     Tail
# 5735       6433      35  0.950103     Tail
# 6180       6945      35  0.950136     Tail
# ...         ...     ...       ...      ...
# 1643       1775       1  0.999996     Tail
# 6510       7309       1  0.999997     Tail
# 4748       5310       1  0.999998     Tail
# 1688       1824       1  0.999999     Tail
# 840         884       1  1.000000     Tail
#
# [2513 rows x 4 columns]

# %%
def get_words(message):
    """Get the normalized list of words from a message string.

    This function should split a message into words, normalize them, and return
    the resulting list. For splitting, you should split on spaces. For normalization,
    you should convert everything to lowercase.

    Args:
        message: A string containing an SMS message

    Returns:
       The list of normalized words from the message.
    """


    words = message
    words = words.split(" ")
    words = [x.lower() for x in words]

    return words



def create_dictionary(messages):
    """Create a dictionary mapping words to integer indices.

    Args:
        messages: A list of strings containing SMS messages

    Returns:
        A python dict mapping words to integers.
    """

    word_counts = collections.defaultdict(int)

    for message in messages:
        for word in set(get_words(message)):
            word_counts[word] += 1

    resulting_dictionary = {}

    for word, count in word_counts.items():
        if count >= 10 and word not in stopwords.words('english') and len(word) > 1:
            next_index = len(resulting_dictionary)
            resulting_dictionary[word] = next_index

    return resulting_dictionary


def transform_text(messages, word_dictionary):
    """Transform a list of text messages into a numpy array for further processing.

    Args:
        messages: A list of strings where each string is an SMS message.
        word_dictionary: A python dict mapping words to integers.

    Returns:
        A numpy array marking the words present in each message.
        Where the component (i,j) is the number of occurrences of the
        j-th vocabulary word in the i-th message.
    """

    A = np.zeros((len(messages), len(word_dictionary)))

    for i, message in enumerate(messages):
        for word in get_words(message):
            if word in word_dictionary:
                A[i, word_dictionary[word]] += 1

    return A

# %%
finalbooks['snippet'] = finalbooks['snippet'].fillna(finalbooks['title'])
finalbooks['snippet'] = finalbooks['snippet'].str.replace(r'[^\w\s]',"")
finalbooks['snippet'] = finalbooks['snippet'].str.replace('-',"")
finalbooks['tag_cloud'] = finalbooks['tag_cloud'].str.replace('-'," ")
finalbooks['snippet'] = finalbooks['snippet'].fillna(finalbooks['tag_cloud'])
finalbooks['words'] = finalbooks['snippet'] +" "+finalbooks['tag_cloud']+" "+finalbooks['first_author']
#finalbooks['words'] = finalbooks['snippet'] +" "+finalbooks['first_author']
dico = create_dictionary(finalbooks['words'])
dico
# Out:
# {'fiction|books': 0,
#  'games': 1,
#  'survivor': 2,
#  'books|own': 3,
#  'place': 4,
#  'losing': 5,
#  'star': 6,
#  'boy': 7,
#  'female': 8,
#  'books|the': 9,
#  'lit|ya': 10,
#  'country': 11,
#  'fantasy|ya': 12,
#  'fi': 13,
#  'stars|i': 14,
#  'favorites|currently': 15,
#  'winning': 16,
#  'adult': 17,
#  'early': 18,
#  'trained': 19,
#  'known': 20,
#  'nation': 21,
#  'own|sci': 22,
#  'fiction|2012': 23,
#  'wealthy': 24,
#  'postapocalyptic': 25,
#  'annual': 26,
#  'punishment': 27,
#  'apocalyptic|my': 28,
#  'whole': 29,
#  'lives': 30,
#  'take': 31,
#  '2010|my': 32,
#  'one': 33,
#  'leaving': 34,
#  'sees': 35,
#  'history': 36,
#  'death': 37,
#  'fiction|ya': 38,
#  'event': 39,
#  'hunger': 40,
#  'male': 41,
#  'young': 42,
#  'ages': 43,
#  'stronger': 44,
#  'fight': 45,
#  'sentence': 46,
#  '18': 47,
#  'collins': 48,
#  'led': 49,
#  'second': 50,
#  'books|scifi': 51,
#  'make': 52,
#  'series|teen': 53,
#  'means': 54,
#  'suzanne': 55,
#  'girl': 56,
#  'nature': 57,
#  'own|read': 58,
#  'claim': 59,
#  'forced': 60,
#  'surrounded': 61,
#  'system': 62,
#  'famous': 63,
#  'reading|young': 64,
#  'selected': 65,
#  'sci': 66,
#  'read|all': 67,
#  'chosen': 68,
#  'reminder': 69,
#  'destruction': 70,
#  'north': 71,
#  'rebellion': 72,
#  'america': 73,
#  'formed': 74,
#  'favorites|ya': 75,
#  '12': 76,
#  'power': 77,
#  'must': 78,
#  'close': 79,
#  'survival': 80,
#  'creation': 81,
#  'bigger': 82,
#  'time': 83,
#  'sister': 84,
#  'grace': 85,
#  'region': 86,
#  'certain': 87,
#  'district': 88,
#  'j.k.': 89,
#  'fantasy|re': 90,
#  'books|my': 91,
#  'potter': 92,
#  'reading|read': 93,
#  'stone': 94,
#  'favorites|on': 95,
#  'favorites|sci': 96,
#  'fi|re': 97,
#  '2016|children': 98,
#  'harry': 99,
#  'books|kids|my': 100,
#  'read|childhood': 101,
#  'rowling': 102,
#  'reads|my': 103,
#  'buy|science': 104,
#  'library|read': 105,
#  'books|audiobook|favorite': 106,
#  'read|favorites|fantasy|currently': 107,
#  '2017|ya': 108,
#  'fiction': 109,
#  'fantasy|read': 110,
#  'bookshelf': 111,
#  'fantasy|children': 112,
#  'story': 113,
#  'irrevocably': 114,
#  'lovers': 115,
#  'school|read': 116,
#  'things': 117,
#  'edward': 118,
#  'part': 119,
#  'love': 120,
#  'book': 121,
#  'series|young': 122,
#  'himand': 123,
#  'twilight': 124,
#  'read|ya': 125,
#  'bookshelf|ya': 126,
#  'favorites|read': 127,
#  'meyer': 128,
#  'mysterious': 129,
#  'know': 130,
#  'bite': 131,
#  'vampires': 132,
#  'dominant': 133,
#  'might': 134,
#  'fiction|guilty': 135,
#  'suspicion': 136,
#  'whose': 137,
#  'fiction|sci': 138,
#  'club|my': 139,
#  'stephenie': 140,
#  'first': 141,
#  'swan': 142,
#  'backdrop': 143,
#  'introduces': 144,
#  'bella': 145,
#  'three': 146,
#  'relationship': 147,
#  'pair': 148,
#  'books|teen': 149,
#  'fiction|finished': 150,
#  'third': 151,
#  'fantasy|owned': 152,
#  'read|did': 153,
#  'saga': 154,
#  'series|ya': 155,
#  'own|chick': 156,
#  'series|first': 157,
#  'absolutely': 158,
#  'books|read': 159,
#  'lit|re': 160,
#  'it|ya': 161,
#  'internationally': 162,
#  'didnt': 163,
#  'author': 164,
#  'favorites|shelfari': 165,
#  'forbidden': 166,
#  'starcrossed': 167,
#  'smalltown': 168,
#  'bestselling': 169,
#  'moving': 170,
#  'childhood': 171,
#  'reading|to': 172,
#  'human': 173,
#  'film': 174,
#  'instant': 175,
#  'southern': 176,
#  'classics|all': 177,
#  'critical': 178,
#  'alabama': 179,
#  'fiction|modern': 180,
#  'masterpiece': 181,
#  'languages': 182,
#  '1961': 183,
#  'harper': 184,
#  'kill': 185,
#  'success': 186,
#  'universal': 187,
#  'literature|favorite': 188,
#  'buy|coming': 189,
#  'fiction|american': 190,
#  'fiction|realistic': 191,
#  'reading|book': 192,
#  'lee': 193,
#  'became': 194,
#  'kindness': 195,
#  'always': 196,
#  'own|5': 197,
#  'books|adult': 198,
#  'cruelty': 199,
#  'published': 200,
#  'regarded': 201,
#  'read': 202,
#  'hatred': 203,
#  'list|american': 204,
#  'awardwinning': 205,
#  'academy': 206,
#  'fiction|literary': 207,
#  'behavior': 208,
#  'books|novel|to': 209,
#  'print': 210,
#  'books|re': 211,
#  'considered': 212,
#  'humor': 213,
#  '1960': 214,
#  'million': 215,
#  'made': 216,
#  'today': 217,
#  'roots': 218,
#  'prize': 219,
#  'read|classics': 220,
#  'stars|read': 221,
#  'crisis': 222,
#  'translated': 223,
#  'woman': 224,
#  'claims': 225,
#  'sleepy': 226,
#  'conscience': 227,
#  'books': 228,
#  'copies': 229,
#  'literature|american': 230,
#  'win': 231,
#  'went': 232,
#  'books|for': 233,
#  'bestseller': 234,
#  'experience': 235,
#  'club|read': 236,
#  'american': 237,
#  'literature': 238,
#  'takes': 239,
#  'reading': 240,
#  'school|my': 241,
#  'appeal': 242,
#  'also': 243,
#  'innocence': 244,
#  'novel': 245,
#  'gilmore': 246,
#  'readers': 247,
#  '2015': 248,
#  'deeply': 249,
#  'simple': 250,
#  'adult|currently': 251,
#  'unforgettable': 252,
#  'later': 253,
#  'forty': 254,
#  'dramatic': 255,
#  'pulitzer': 256,
#  'town': 257,
#  'school|to': 258,
#  'features': 259,
#  'books|literary': 260,
#  'fiction|classics': 261,
#  'new': 262,
#  'island': 263,
#  'scholar': 264,
#  'jay': 265,
#  'buy|all': 266,
#  'own|young': 267,
#  'daisy': 268,
#  'century|to': 269,
#  'james': 270,
#  'isbn13': 271,
#  'classic': 272,
#  'times': 273,
#  'foreword': 274,
#  'jazz': 275,
#  'crafted': 276,
#  'tale': 277,
#  'west': 278,
#  'shelf': 279,
#  'cover': 280,
#  'again|read': 281,
#  'scott': 282,
#  'personal': 283,
#  'york': 284,
#  'fiction|my': 285,
#  'sex': 286,
#  'generations': 287,
#  'authors': 288,
#  'school|american': 289,
#  'quintessential': 290,
#  'text': 291,
#  'eleanor': 292,
#  'favorites|to': 293,
#  'books|library|my': 294,
#  'parties': 295,
#  'fiction|20th': 296,
#  'obsession': 297,
#  '1920s': 298,
#  'books|high': 299,
#  'high': 300,
#  'twentiethcentury': 301,
#  'supreme': 302,
#  'exquisitely': 303,
#  'note': 304,
#  'reads|stand': 305,
#  'f.': 306,
#  'edition': 307,
#  'award': 308,
#  'achievement': 309,
#  'long': 310,
#  'fiction|novel|read': 311,
#  'winner': 312,
#  'beautiful': 313,
#  'drink': 314,
#  'classics|read': 315,
#  'fiction|to': 316,
#  'updated': 317,
#  'introduction': 318,
#  'literature|owned': 319,
#  'fitzgerald': 320,
#  'acclaimed': 321,
#  'true': 322,
#  'stands': 323,
#  'york|read': 324,
#  'read|to': 325,
#  'it|read': 326,
#  'lit|modern': 327,
#  'iii': 328,
#  'lavish': 329,
#  '2013|1001': 330,
#  'include': 331,
#  'isbn': 332,
#  '2012|1001': 333,
#  'great': 334,
#  'read|favorite': 335,
#  'school|re': 336,
#  'national': 337,
#  'alternate': 338,
#  'mysteriously': 339,
#  'final': 340,
#  'reread|read': 341,
#  '2016|read': 342,
#  'career': 343,
#  'books|classic': 344,
#  'age': 345,
#  'books|favorite': 346,
#  'raw': 347,
#  'fiction|re': 348,
#  'funny': 349,
#  'bought': 350,
#  'library|ya': 351,
#  'bold': 352,
#  'kid': 353,
#  'fault': 354,
#  'fiction|e': 355,
#  'books|made': 356,
#  'read|young': 357,
#  'books|2014': 358,
#  'group': 359,
#  '2014|owned': 360,
#  'never': 361,
#  'waters': 362,
#  'books|general': 363,
#  'chapter': 364,
#  'despite': 365,
#  'twist': 366,
#  'favorites|e': 367,
#  'cancer': 368,
#  'years': 369,
#  'irreverent': 370,
#  'tragic': 371,
#  'plot': 372,
#  '2012|read': 373,
#  'named': 374,
#  'own|contemporary': 375,
#  'terminal': 376,
#  'green': 377,
#  'read|own': 378,
#  'miracle': 379,
#  'reads|teen': 380,
#  '2013|2014': 381,
#  'alone|read': 382,
#  'work': 383,
#  'heartbreaking': 384,
#  'business': 385,
#  'fiction|book': 386,
#  'brilliantly': 387,
#  'ambitious': 388,
#  'stars': 389,
#  'diagnosis': 390,
#  'exploring': 391,
#  'upon': 392,
#  'alive': 393,
#  'romance|i': 394,
#  'anything': 395,
#  '2012|ya': 396,
#  '2014|coming': 397,
#  'medical': 398,
#  'gorgeous': 399,
#  'support': 400,
#  'completely': 401,
#  'thrilling': 402,
#  'appears': 403,
#  'read|read': 404,
#  'yet': 405,
#  'suddenly': 406,
#  'john': 407,
#  'buy|read': 408,
#  'ring': 409,
#  'tolkien': 410,
#  'literature|fantasy': 411,
#  'timeless': 412,
#  'library|1001': 413,
#  'cruel': 414,
#  'ends': 415,
#  'adventures': 416,
#  'fiction|5': 417,
#  'spectacular': 418,
#  'wizard': 419,
#  'eat': 420,
#  'dangerous': 421,
#  'grade|read': 422,
#  'lived': 423,
#  'ground': 424,
#  'powerful': 425,
#  '2001': 426,
#  'bookshelf|read': 427,
#  'children': 428,
#  'magnificent': 429,
#  'stars|sci': 430,
#  'includes': 431,
#  'fantasy|currently': 432,
#  'scifi|own': 433,
#  'century|read': 434,
#  'met': 435,
#  'world': 436,
#  'fiction|personal': 437,
#  'douglas': 438,
#  'literature|read': 439,
#  'favorites|fiction': 440,
#  'fantasy|sci': 441,
#  'reluctant': 442,
#  'smell': 443,
#  'dirty': 444,
#  'based': 445,
#  'nasty': 446,
#  'paperback': 447,
#  'bare': 448,
#  'hold|to': 449,
#  'acclaim': 450,
#  's|my': 451,
#  '2014|childhood': 452,
#  'britain': 453,
#  '1937': 454,
#  'recognized': 455,
#  'recounts': 456,
#  'favorites|children': 457,
#  'wet': 458,
#  'dry': 459,
#  'books|i': 460,
#  'anderson': 461,
#  'modern': 462,
#  'sit': 463,
#  '2015|fantasy': 464,
#  'fantasy|all': 465,
#  'classics': 466,
#  'books|to': 467,
#  'hole': 468,
#  'hero': 469,
#  'nothing': 470,
#  'dragon': 471,
#  'filled': 472,
#  'complex': 473,
#  'classics|school': 474,
#  'voices': 475,
#  'read|currently': 476,
#  'perhaps': 477,
#  'faithful': 478,
#  'child': 479,
#  'yorker': 480,
#  'since': 481,
#  'sexuality': 482,
#  'keeps': 483,
#  'pain': 484,
#  '2013|read': 485,
#  'fiction|i': 486,
#  '1951': 487,
#  'born': 488,
#  'written': 489,
#  'hopelessly': 490,
#  'mixed': 491,
#  'portrayal': 492,
#  'issues': 493,
#  'favorites|must': 494,
#  'cry': 495,
#  '100': 496,
#  'heart': 497,
#  'library': 498,
#  'higher': 499,
#  'sixteen': 500,
#  '2015|to': 501,
#  'own|adult': 502,
#  '2005': 503,
#  'description': 504,
#  'pleasure': 505,
#  'library|american': 506,
#  'literature|high': 507,
#  'orders': 508,
#  'frequently': 509,
#  'almost': 510,
#  'keep': 511,
#  'us': 512,
#  'tend': 513,
#  'use': 514,
#  'city': 515,
#  'aside': 516,
#  'gives': 517,
#  'adult|books': 518,
#  'list': 519,
#  'eloquent': 520,
#  'j.d.': 521,
#  'many': 522,
#  'underground': 523,
#  'books|book': 524,
#  '2014|read': 525,
#  'novels': 526,
#  'circumstances': 527,
#  'reader': 528,
#  '20th': 529,
#  '2016|my': 530,
#  'every': 531,
#  'beauty': 532,
#  'childrens': 533,
#  'buy|1001': 534,
#  'read|literary': 535,
#  'school': 536,
#  'favorites|general': 537,
#  'perfectly': 538,
#  'jd': 539,
#  'fiction|read': 540,
#  'included': 541,
#  'however': 542,
#  'challenged': 543,
#  'remaining': 544,
#  'list|historical': 545,
#  'thing': 546,
#  'ancient': 547,
#  '1950s': 548,
#  'goes': 549,
#  'fiction|all': 550,
#  'wants': 551,
#  'century': 552,
#  'attracted': 553,
#  'like': 554,
#  'native': 555,
#  'best': 556,
#  'court': 557,
#  'pennsylvania': 558,
#  'read|modern': 559,
#  'say': 560,
#  'leaves': 561,
#  'poets': 562,
#  'away': 563,
#  'fiction|rory': 564,
#  'teenage': 565,
#  'handle': 566,
#  'literature|school': 567,
#  'voice': 568,
#  'days': 569,
#  'sets': 570,
#  'favorites|book': 571,
#  'books|murder': 572,
#  'library|i': 573,
#  'brown': 574,
#  'demons': 575,
#  'literature|all': 576,
#  'thriller|historical': 577,
#  'library|realistic': 578,
#  'angels': 579,
#  'dan': 580,
#  'books|currently': 581,
#  'buy|crime': 582,
#  'robert': 583,
#  'reads|1001': 584,
#  'favorites|literary': 585,
#  'studio': 586,
#  'once|to': 587,
#  'lit|own': 588,
#  'jane': 589,
#  'book|e': 590,
#  'un': 591,
#  'library|to': 592,
#  'al': 593,
#  'lit|my': 594,
#  'del': 595,
#  '2016|high': 596,
#  'literature|re': 597,
#  'far': 598,
#  'la': 599,
#  'darcy': 600,
#  'favourites|e': 601,
#  'english|on': 602,
#  'come': 603,
#  'elizabeth': 604,
#  'books|british': 605,
#  'da': 606,
#  'una': 607,
#  'books|1001': 608,
#  'hold|read': 609,
#  'books|all': 610,
#  'literature|my': 611,
#  'con': 612,
#  'austen': 613,
#  'member': 614,
#  'possibility': 615,
#  'price': 616,
#  'beloved': 617,
#  'last': 618,
#  'choice': 619,
#  'favorites|i': 620,
#  'afghanistan': 621,
#  'past': 622,
#  'ruling': 623,
#  'boys': 624,
#  'dying': 625,
#  'constant': 626,
#  'servant': 627,
#  'thirty': 628,
#  'unusual': 629,
#  'redemption': 630,
#  'betrayal': 631,
#  'happens': 632,
#  'read|historical': 633,
#  'read|book': 634,
#  'sweeping': 635,
#  'unlikely': 636,
#  'process': 637,
#  'increasing': 638,
#  'back': 639,
#  'right': 640,
#  'course': 641,
#  'own|owned|book': 642,
#  'family': 643,
#  'exploration': 644,
#  'may': 645,
#  'friendship': 646,
#  'companion': 647,
#  'beautifully': 648,
#  'sacrifices': 649,
#  'runner': 650,
#  'distant': 651,
#  'devastating': 652,
#  'son': 653,
#  'fathers': 654,
#  'even': 655,
#  'sometimes': 656,
#  'fiction|non': 657,
#  'challenge|modern': 658,
#  'club': 659,
#  'strong': 660,
#  'own|my': 661,
#  'fiction|owned': 662,
#  'destroyed': 663,
#  'two': 664,
#  'become': 665,
#  'friend': 666,
#  'books|realistic': 667,
#  'single': 668,
#  'day': 669,
#  'torn': 670,
#  'set': 671,
#  'impoverished': 672,
#  'bond': 673,
#  'wrenching': 674,
#  'reads|read': 675,
#  'abandon': 676,
#  'lifetime': 677,
#  'tensions': 678,
#  'political': 679,
#  'journeys': 680,
#  'told': 681,
#  'ever': 682,
#  'religious': 683,
#  'try': 684,
#  'merchant': 685,
#  'amidst': 686,
#  'apart': 687,
#  'change': 688,
#  'alone': 689,
#  'shes': 690,
#  'kept': 691,
#  'surprises': 692,
#  'year': 693,
#  'extreme': 694,
#  '2011|to': 695,
#  'discovers': 696,
#  'tests': 697,
#  'veronica': 698,
#  'follows': 699,
#  'live': 700,
#  '2013|my': 701,
#  'intelligent': 702,
#  'hidden': 703,
#  'determine': 704,
#  'read|first': 705,
#  'conflict': 706,
#  'competitive': 707,
#  'divided': 708,
#  'transforms': 709,
#  'reads|ya': 710,
#  'warned': 711,
#  'growing': 712,
#  'destroy': 713,
#  'perfect': 714,
#  'threaten': 715,
#  'own|re': 716,
#  'alongside': 717,
#  'fiction|post': 718,
#  'five': 719,
#  'unrest': 720,
#  'fellow': 721,
#  'chicago': 722,
#  'including': 723,
#  'intense': 724,
#  'life': 725,
#  'secret': 726,
#  'friends': 727,
#  'beatrice': 728,
#  'struggles': 729,
#  'factions': 730,
#  'makes': 731,
#  'dystopian': 732,
#  'rest': 733,
#  'loves': 734,
#  'highly': 735,
#  'fascinating': 736,
#  'dedicated': 737,
#  'staying': 738,
#  'exactly': 739,
#  'fits': 740,
#  'psychological': 741,
#  'fiction|coming': 742,
#  'cant': 743,
#  'particular': 744,
#  'peaceful': 745,
#  'save': 746,
#  'unravel': 747,
#  'together': 748,
#  'series|on': 749,
#  'decision': 750,
#  'brave': 751,
#  'bookshelf|book': 752,
#  'seemingly': 753,
#  'roth': 754,
#  'learns': 755,
#  'series': 756,
#  'everyone': 757,
#  'physical': 758,
#  'age|ya': 759,
#  'society': 760,
#  '2013|ya': 761,
#  'endurance': 762,
#  'mean': 763,
#  'really': 764,
#  'honest': 765,
#  'fantasy|e': 766,
#  'help': 767,
#  'consequences': 768,
#  'romance': 769,
#  'required': 770,
#  'fiction|must': 771,
#  'version': 772,
#  'grows': 773,
#  'attempt': 774,
#  'club|classic': 775,
#  'vision': 776,
#  'english|fantasy': 777,
#  'reading|books': 778,
#  'rare': 779,
#  'television': 780,
#  'find': 781,
#  'terrifying': 782,
#  'seminal': 783,
#  'lifethe': 784,
#  'buy|to': 785,
#  'ability': 786,
#  'students': 787,
#  'nineteen': 788,
#  'fiction|classic': 789,
#  'brilliance': 790,
#  'real': 791,
#  'fantasy|classic': 792,
#  'poor': 793,
#  'orwell': 794,
#  'favorites|rory': 795,
#  'george': 796,
#  'read|general': 797,
#  'list|to': 798,
#  'becomes': 799,
#  'hell': 800,
#  'among': 801,
#  'haunting': 802,
#  'fiction|science': 803,
#  'ranks': 804,
#  'offers': 805,
#  'century|modern': 806,
#  'library|school': 807,
#  'nightmare': 808,
#  'texts': 809,
#  'fiction|novels|to': 810,
#  'fiction|general': 811,
#  'buy|for': 812,
#  'books|history|read': 813,
#  '1936': 814,
#  'read|classic': 815,
#  'read|social': 816,
#  'school|1001': 817,
#  'school|classic': 818,
#  'read|my': 819,
#  '2017|read': 820,
#  '2014|must': 821,
#  '2013': 822,
#  '1945': 823,
#  'fiction|british': 824,
#  '2016|i': 825,
#  'spirit': 826,
#  'facing': 827,
#  'teenager': 828,
#  'vulnerable': 829,
#  's|all': 830,
#  'conditions': 831,
#  'foremost': 832,
#  'confined': 833,
#  'war': 834,
#  'fiction|world': 835,
#  'extraordinary': 836,
#  'newly': 837,
#  'meet': 838,
#  'books|childhood': 839,
#  'century|i': 840,
#  'biography|true': 841,
#  'wry': 842,
#  'discovered': 843,
#  'amsterdam': 844,
#  'hid': 845,
#  'frank': 846,
#  'books|rory': 847,
#  'library|high': 848,
#  'father': 849,
#  'non': 850,
#  'memoir|auto': 851,
#  'attic': 852,
#  'read|5': 853,
#  'views': 854,
#  'books|wish': 855,
#  'anne': 856,
#  'challenge|to': 857,
#  'candid': 858,
#  'rebellious': 859,
#  'mother': 860,
#  'vital': 861,
#  'companions': 862,
#  'books|historical': 863,
#  'fear': 864,
#  'writes': 865,
#  'observations': 866,
#  'reads|children': 867,
#  'affection': 868,
#  'testament': 869,
#  'diary': 870,
#  'petty': 871,
#  'beyond': 872,
#  'nazis': 873,
#  'teenagers': 874,
#  'discovery': 875,
#  'wisdom': 876,
#  'passages': 877,
#  'own|for': 878,
#  'authors|own': 879,
#  'originally': 880,
#  'han': 881,
#  'historia': 882,
#  'book|shelfari': 883,
#  'crime|my': 884,
#  'list|read': 885,
#  'library|crime': 886,
#  'own|mystery': 887,
#  'en': 888,
#  'mystery|audio': 889,
#  'sin': 890,
#  'thriller|book': 891,
#  'researcher': 892,
#  'finish|thriller': 893,
#  'thriller|general': 894,
#  'harriet': 895,
#  'men': 896,
#  'millennium': 897,
#  'mystery|read': 898,
#  'favorites|favorite': 899,
#  'testing': 900,
#  'happy': 901,
#  'afraid': 902,
#  'own|ya': 903,
#  'longtime': 904,
#  'surprising': 905,
#  'shock': 906,
#  'odds': 907,
#  'returned': 908,
#  'trilogy': 909,
#  'fueled': 910,
#  'turn': 911,
#  'shelf|read': 912,
#  'miraculously': 913,
#  'stop': 914,
#  'books|on': 915,
#  'turned': 916,
#  'adventure|read': 917,
#  'stakes': 918,
#  'whispers': 919,
#  'prove': 920,
#  'doubt': 921,
#  'holds': 922,
#  'sparks': 923,
#  'helped': 924,
#  'fiction|favorite': 925,
#  'wishes': 926,
#  'still': 927,
#  'near': 928,
#  'fantasy|science': 929,
#  'tribute': 930,
#  'tour': 931,
#  'lost': 932,
#  'icy': 933,
#  'buy|e': 934,
#  'victory': 935,
#  'english|my': 936,
#  'movie|read': 937,
#  'draws': 938,
#  'books|sci': 939,
#  'continues': 940,
#  'distance': 941,
#  'stars|young': 942,
#  'fi|book': 943,
#  'fi|to': 944,
#  'convinced': 945,
#  'reads|book': 946,
#  'fire': 947,
#  'shadow': 948,
#  'without': 949,
#  'entirely': 950,
#  'way': 951,
#  'visit': 952,
#  'cannot': 953,
#  'magical': 954,
#  '2016|to': 955,
#  'series|childhood': 956,
#  'aching': 957,
#  'heartwarming': 958,
#  'revelations': 959,
#  'black': 960,
#  'defense': 961,
#  'full': 962,
#  'matter': 963,
#  'catches': 964,
#  'across': 965,
#  'broken': 966,
#  'teacher': 967,
#  'often': 968,
#  'safety': 969,
#  'fill': 970,
#  '2017|favorite': 971,
#  'could': 972,
#  'hes': 973,
#  'frightening': 974,
#  'meanwhile': 975,
#  'closer': 976,
#  'guards': 977,
#  'usual': 978,
#  'literature|children': 979,
#  'evil': 980,
#  'harrys': 981,
#  'learned': 982,
#  'highstakes': 983,
#  'poignant': 984,
#  'installment': 985,
#  'fantasy|middle': 986,
#  'education': 987,
#  'heights': 988,
#  'prison': 989,
#  'series|own': 990,
#  'hunting': 991,
#  'books|children': 992,
#  'relative': 993,
#  'cute': 994,
#  'imagine': 995,
#  'seems': 996,
#  'eye': 997,
#  'buy|on': 998,
#  'anyone': 999,
#  ...}

# %%
len(dico)
# Out:
# 11200

# %%
A = transform_text(finalbooks['words'], dico)

# %%
np.size(A, 0)
# Out:
# 8000

# %%
np.sum(A, axis=1).min()
# Out:
# 6.0

# %%
A1 = np.sum((A>0), axis= 0)

IDF = np.log(np.size(A, 0)/A1)
IDF
len(IDF)
# Out:
# 11200

# %%
TF = A / (np.sum(A, axis=1, keepdims=True))
np.shape(TF)
# Out:
# (8000, 11200)

# %%
TFiDF= TF*IDF
np.shape(TFiDF)
# Out:
# (8000, 11200)

# %%
#ids = np.argsort(TFiDF.mean(axis=1))[:5]
#reverse_dictionary = {i: word for word, i in dico.items()}
#[reverse_dictionary[i] for i in ids]

# %%
TFiDF = TFiDF / np.sqrt((np.sum(TFiDF**2, axis = 1, keepdims=True)+0.01))

# %%
SimC = np.dot(TFiDF, TFiDF.T)

# %%
SimC
# Out:
# array([[0.96164977, 0.02911102, 0.00524494, ..., 0.00446057, 0.00878316,
#         0.03299201],
#        [0.02911102, 0.98739694, 0.00946556, ..., 0.        , 0.00676241,
#         0.00110098],
#        [0.00524494, 0.00946556, 0.97151082, ..., 0.00384577, 0.00215187,
#         0.00315417],
#        ...,
#        [0.00446057, 0.        , 0.00384577, ..., 0.98239163, 0.        ,
#         0.00138774],
#        [0.00878316, 0.00676241, 0.00215187, ..., 0.        , 0.96382747,
#         0.0092722 ],
#        [0.03299201, 0.00110098, 0.00315417, ..., 0.00138774, 0.0092722 ,
#         0.96017134]])

# %%
np.sum(SimC, axis = 1).max()
# Out:
# 210.53071341774012

# %%
np.fill_diagonal(SimC, 1)

# %%
SimC
# Out:
# array([[1.        , 0.02911102, 0.00524494, ..., 0.00446057, 0.00878316,
#         0.03299201],
#        [0.02911102, 1.        , 0.00946556, ..., 0.        , 0.00676241,
#         0.00110098],
#        [0.00524494, 0.00946556, 1.        , ..., 0.00384577, 0.00215187,
#         0.00315417],
#        ...,
#        [0.00446057, 0.        , 0.00384577, ..., 1.        , 0.        ,
#         0.00138774],
#        [0.00878316, 0.00676241, 0.00215187, ..., 0.        , 1.        ,
#         0.0092722 ],
#        [0.03299201, 0.00110098, 0.00315417, ..., 0.00138774, 0.0092722 ,
#         1.        ]])

# %%
BookSim =pd.DataFrame(SimC, columns=finalbooks.title, index=finalbooks.title)

# %%
#np.argsort(SimC[53, :])[-5:]
finalbooks.title[np.argsort(SimC[15, :])[-6:]]
#Sim20 = pd.DataFrame(Sim20, columns=finalbooks.title[101:200], index=finalbooks.title[50:60])
# Out:
# 3481                 The Exiled Queen (Seven Realms, #2)
# 940                                            The Hours
# 5330               The Readers of Broken Wheel Recommend
# 3607                          The Universe in a Nutshell
# 4731                            Min kamp 1 (Min kamp #1)
# 15      The Girl with the Dragon Tattoo (Millennium, #1)
# Name: title, dtype: object

# %%
SimC[15, [15, 2252, 6977, 4642, 2796, 1700 ]]
# Out:
# array([1.        , 0.10070519, 0.00777199, 0.        , 0.00343411,
#        0.09201347])

# %%
finalbooks [finalbooks.newbookid.isin(np.argsort(SimC[15, :])[-6:]+1)]
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 15         16            2429135       2429135   1708725          274
# 940       941              11899         11899   2245431          138
# 3481     3563            7801229       7801229   9842102           22
# 3607     3696               2095          2095   1978857           80
# 4731     4969            7147831       7147831   7412679           93
# 5330     5687           25573977      25573977  25758335           63
#
#             isbn        isbn13                         authors  \
# 15     307269752  9.780307e+12      Stieg Larsson, Reg Keeland
# 940    312305060  9.780312e+12              Michael Cunningham
# 3481  1423118243  9.781423e+12            Cinda Williams Chima
# 3607  055380202X  9.780554e+12                 Stephen Hawking
# 4731         NaN  9.788253e+12              Karl Ove Knausgård
# 5330  149262344X  9.781493e+12  Katarina Bivald, Alice Menzies
#
#       original_publication_year                        original_title  ...  \
# 15                       2005.0                 Män som hatar kvinnor  ...
# 940                      1998.0                             The Hours  ...
# 3481                     2010.0                      The Exiled Queen  ...
# 3607                     2001.0            The Universe in a Nutshell  ...
# 4731                     2009.0                            Min kamp 1  ...
# 5330                     2013.0  Läsarna i Broken Wheel rekommenderar  ...
#
#      ratings_5                                          image_url  \
# 15      836050  https://images.gr-assets.com/books/1327868566m...
# 940      35489  https://images.gr-assets.com/books/1479663379m...
# 3481     18077  https://images.gr-assets.com/books/1285276245m...
# 3607      9920  https://images.gr-assets.com/books/1159814395m...
# 4731      7729  https://images.gr-assets.com/books/1262695721m...
# 5330      3588  https://images.gr-assets.com/books/1452107441m...
#
#                                         small_image_url  newbookid  \
# 15    https://images.gr-assets.com/books/1327868566s...         16
# 940   https://images.gr-assets.com/books/1479663379s...        941
# 3481  https://images.gr-assets.com/books/1285276245s...       3482
# 3607  https://images.gr-assets.com/books/1159814395s...       3608
# 4731  https://images.gr-assets.com/books/1262695721s...       4732
# 5330  https://images.gr-assets.com/books/1452107441s...       5331
#
#                                               tag_cloud  firstgenre  \
# 15    to read|currently reading|fiction|mystery|favo...     to-read
# 940   fiction|currently reading|historical fiction|p...     fiction
# 3481  to read|fantasy|favorites|young adult|currentl...     to-read
# 3607  to read|physics|science|non fiction|nonfiction...     to-read
# 4731  to read|non fiction|biography|norwegian|contem...     to-read
# 5330  to read|fiction|currently reading|books about ...     to-read
#
#                                                 snippet      pages  \
# 15    Mikael Blomkvist ekonomireporter döms till fän...  566 pages
# 940   Una mañana de 1923 en un suburbio de Londres V...  230 pages
# 3481  Haunted by the loss of his mother and sister H...  586 pages
# 3607  Stephen Hawking uno de los pensadores más infl...  216 pages
# 4731  Romanen åpner med en svimlende beskrivelse av ...  435 pages
# 5330  Allting börjar med en brevväxling mellan två h...  396 pages
#
#               first_author                                              words
# 15           Stieg Larsson  Mikael Blomkvist ekonomireporter döms till fän...
# 940     Michael Cunningham  Una mañana de 1923 en un suburbio de Londres V...
# 3481  Cinda Williams Chima  Haunted by the loss of his mother and sister H...
# 3607       Stephen Hawking  Stephen Hawking uno de los pensadores más infl...
# 4731    Karl Ove Knausgård  Romanen åpner med en svimlende beskrivelse av ...
# 5330       Katarina Bivald  Allting börjar med en brevväxling mellan två h...
#
# [6 rows x 30 columns]

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(27.5, 22.5))

# Generate a custom diverging colormap followed by the correlation heatmap
cmap =sns.diverging_palette(20, 220, n=20000)

sns.heatmap(BookSim, cmap=cmap,center = 0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:xlabel='title', ylabel='title'>

# %%
train
# Out:
#          rating  newbookid  newuser_id
# 0             3       1810        8137
# 1             4        596        5455
# 2             2        418       12769
# 3             5       6563        6942
# 4             5        231        4026
# ...         ...        ...         ...
# 1690145       4        293       14443
# 1690146       4         44        4440
# 1690147       2        182       11177
# 1690148       5          4       10078
# 1690149       4        353       13948
#
# [1690150 rows x 3 columns]

# %%
allpreds = []
train = train.sort_values(by=['newbookid'])
for i in range(15000):
  bi = train.newbookid[train.newuser_id == i+1]-1
  Simi = SimC[:, bi]
  ri = np.array(train[train.newuser_id == i+1].sort_values(by=['newbookid']).rating)
  predi = finalbooks.filter(['newbookid'])
  predi['pred'] = np.sum(Simi*ri, axis=1)/(np.sum(Simi, axis=1)+0.01)
  predi['newuser_id'] = i+1
  allpreds.append(predi)
  if (i+1)%1000 == 0: print("done: ", i+1)
# Out:
# done:  1000
# done:  2000
# done:  3000
# done:  4000
# done:  5000
# done:  6000
# done:  7000
# done:  8000
# done:  9000
# done:  10000
# done:  11000
# done:  12000
# done:  13000
# done:  14000
# done:  15000

# %%
predictions = np.concatenate(allpreds, axis=0 )
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-54-f041da35ba27> in <module>
# ----> 1 predictions = np.concatenate(allpreds, axis=0 )
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 2.68 GiB for an array with shape (120000000, 3) and data type float64

# %%
final =pd.DataFrame(predictions, columns=['newbookid', 'pred', 'newuser_id'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eca42dd42942> in <module>
# ----> 1 final =pd.DataFrame(predictions, columns=['newbookid', 'pred', 'newuser_id'])
#
# NameError: name 'pd' is not defined

# %%
train['conc']=train['newuser_id'].map(str)+train['newbookid'].map(str)
final['conc']=final['newuser_id'].map(str)+final['newbookid'].map(str)
finalfin = final[~final.conc.isin(train.conc)]
finalfin.describe()

# %%
finalrank = test.merge(final,on = ['newbookid', 'newuser_id'])
finalrank = finalrank.sort_values(by=['newuser_id', 'pred'], ascending=False)
finalrank.head(5)

# %%
finallist = []
for i in range(15000):
    a = finalrank.loc[finalrank.newuser_id == i+1]['rating'].tolist()
    finallist.append(a)
    if (i+1)%1000 == 0: print("done: ", i+1)

# %%
b = np.array([ndcg_k(r, len(r)) for r in finallist])


facet, axes = plt.subplots(1, 1, figsize=(10, 3))
n, bins, patches = plt.hist(b, 200, facecolor='blue', alpha=0.5) #, log = True)   
plt.title('Distribution of NDGC among Users for the TFiDF model')
plt.show()

# [ndcg_k(r, len(r)) for r in poplista]

# %%
d = b[b == 1]
sum(d)/15000

# %%
top10 = finalfin.sort_values('pred',ascending = False).groupby('newuser_id').head(10)
top50 = finalfin.sort_values('pred',ascending = False).groupby('newuser_id').head(50)

print('(1) TF-iDF Model RMSE: ', np.round(rmse(finalrank['pred'],finalrank['rating']), decimals=3))
print('(2) TF-iDF Model NDCG: ', np.round(mean_ndcg(finallist), decimals=3))
print("(2) Median NDCG: ", np.round(np.median(b), decimals=3))
print("(2) Share of NDCG =1 among Users: ", np.round(sum(d)/15000, decimals=3))
print('(3) TF-iDF Model Div10 Score: ',np.round(sum(np.in1d(top10.newbookid, tail.newbookid))/len(top10), decimals=3))
print('(3) TF-iDF Model Div50 Score: ',np.round(sum(np.in1d(top50.newbookid, tail.newbookid))/len(top50), decimals=3))

# %%
finalranktrain = train.merge(final,on = ['newbookid', 'newuser_id'])
finalranktrain = finalranktrain.sort_values(by=['newuser_id', 'pred'], ascending=False)

# %%
finalranktrain

# %%
finallisttrain = []
for i in range(15000):
    a = finalranktrain.loc[finalranktrain.newuser_id == i+1]['rating'].tolist()
    finallisttrain.append(a)
    if (i+1)%1000 == 0: print("done: ", i+1)

# %%
print('(1) TF-iDF Train Model RMSE: ', np.round(rmse(finalranktrain['pred'],finalranktrain['rating']), decimals=3))
print('(2) TF-iDF Train Model NDCG: ', np.round(mean_ndcg(finallisttrain), decimals=3))
